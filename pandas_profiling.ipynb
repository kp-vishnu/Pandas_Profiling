# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\Priya\Downloads\Landslides.csv")
data.head()
# Out:
#    id      date time         country                        nearest_places  \
# 0   1  1/2/2007  NaN  United Kingdom                   Whitehaven, Cumbria
# 1   2  1/3/2007  NaN            Peru  Alto Mesapata, in the Pasco province
# 2   3  1/5/2007  NaN          Brazil         Nova Friburgo, Rio de Janeiro
# 3   4  1/5/2007  NaN          Brazil             Sumidouro, Rio de Janeiro
# 4   5  1/5/2007  NaN          Brazil                    Jundiai, Sao Paulo
#
#   hazard_type landslide_type trigger storm_name  fatalities  ...  population  \
# 0   landslide      Landslide    Rain        NaN         1.0  ...     24803.0
# 1   landslide        Complex    Rain        NaN         NaN  ...         0.0
# 2   landslide      Landslide    Rain        NaN         7.0  ...    153361.0
# 3   landslide      Landslide    Rain        NaN         2.0  ...     11555.0
# 4   landslide      Landslide    Rain        NaN         1.0  ...     54415.0
#
#   countrycode continentcode        key version  \
# 0          GB            EU  sGaiIKdcW     1.0
# 1          PE            SA  S95OsumK4     1.0
# 2          BR            SA  D5vlNdgB7     1.0
# 3          BR            SA  h5J8IFdc4     1.0
# 4          BR            SA  s5Zb5FdB4     1.0
#
#                                     tstamp changeset_id   latitude  longitude  \
# 0  Tue Apr 01 2014 00:00:00 GMT+0000 (UTC)          1.0  54.549400  -3.587500
# 1  Tue Apr 01 2014 00:00:00 GMT+0000 (UTC)          1.0 -10.383800 -75.426700
# 2  Tue Apr 01 2014 00:00:00 GMT+0000 (UTC)          1.0 -22.282346 -42.536362
# 3  Tue Apr 01 2014 00:00:00 GMT+0000 (UTC)          1.0 -22.045200 -42.673400
# 4  Tue Apr 01 2014 00:00:00 GMT+0000 (UTC)          1.0 -23.231100 -46.613600
#
#                                   geolocation
# 0   (54.549399999999999, -3.5874999999999999)
# 1  (-10.383800000000001, -75.426699999999997)
# 2  (-22.282346350000001, -42.536362050000001)
# 3  (-22.045200000000001, -42.673400000000001)
# 4  (-23.231100000000001, -46.613599999999998)
#
# [5 rows x 34 columns]

# %%
import pandas_profiling as pp

# %%
profile = pp.ProfileReport(data)
profile.to_file("output.html")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_39280/1790750967.py in <module>
# ----> 1 profile = pp.ProfileReport(data)
#       2 profile.to_file("output.html")
#
# ~\Anaconda3\lib\site-packages\pandas_profiling\__init__.py in __init__(self, df, **kwargs)
#      64         sample = kwargs.get('sample', df.head())
#      65
# ---> 66         description_set = describe(df, **kwargs)
#      67
#      68         self.html = to_html(sample,
#
# ~\Anaconda3\lib\site-packages\pandas_profiling\describe.py in describe(df, bins, check_correlation, correlation_threshold, correlation_overrides, check_recoded, pool_size, **kwargs)
#     390             if name not in names:
#     391                 names.append(name)
# --> 392     variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
#     393     variable_stats.columns.names = df.columns.names
#     394
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                 and p.name not in allow_args
#     310             )
# --> 311             else p
#     312             for p in old_sig.parameters.values()
#     313         ]
#
# TypeError: concat() got an unexpected keyword argument 'join_axes'
